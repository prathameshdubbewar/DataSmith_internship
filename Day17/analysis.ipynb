# %%
import pandas as pd

# %%
# df = pd.read_excel('InternDataSajaa.xlsx')

# %%
# df.to_csv('Well_miningDS.csv')

# %%
df = pd.read_csv('Well_miningDS.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Index', 'Well', 'Leg', 'Formation', 'Biozone',
#        'Measured Depth (ft)', 'Footage Drilled / hr ', 'WHP (psig)',
#        'SiBHP (psig)', 'BHP (psig)', 'Difference',
#        'Reservoir Gas Rate (MMSCF/D)', 'BHT (DegF)',
#        'Comments, post SNOC input'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0  Index      Well    Leg Formation           Biozone  \
# 0              0      0  SAJAA-01  LEG C   SHUAIBA            19_S10
# 1              1      1  SAJAA-01  LEG C   KHARAIB             2_K90
# 2              2      2  SAJAA-01  LEG C   KHARAIB      20_K80 UPPER
# 3              3      3  SAJAA-01  LEG C   KHARAIB  21_K80 MID/LOWER
# 4              4      4  SAJAA-01  LEG C   KHARAIB  21_K80 MID/LOWER
# ...          ...    ...       ...    ...       ...               ...
# 1497        1497   1775  SAJAA-06  LEG D   HABSHAN            43_H90
# 1498        1498   1776  SAJAA-06  LEG D   HABSHAN            43_H90
# 1499        1499   1777  SAJAA-06  LEG D   HABSHAN            43_H90
# 1500        1500   1778  SAJAA-06  LEG D   HABSHAN            43_H90
# 1501        1501   1779  SAJAA-06  LEG D   HABSHAN            43_H90
#
#       Measured Depth (ft)  Footage Drilled / hr   WHP (psig)  SiBHP (psig)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    1502 non-null   int64
#  1   Index                         1502 non-null   int64
#  2   Well                          1502 non-null   object
#  3   Leg                           1502 non-null   object
#  4   Formation                     1502 non-null   object
#  5   Biozone                       1500 non-null   object
#  6   Measured Depth (ft)           1501 non-null   float64
#  7   Footage Drilled / hr          1501 non-null   float64
#  8   WHP (psig)                    1502 non-null   float64
#  9   SiBHP (psig)                  1502 non-null   int64
#  10  BHP (psig)                    1502 non-null   int64
#  11  Difference                    271 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# Index                              0
# Well                               0
# Leg                                0
# Formation                          0
# Biozone                            2
# Measured Depth (ft)                1
# Footage Drilled / hr               1
# WHP (psig)                         0
# SiBHP (psig)                       0
# BHP (psig)                         0
# Difference                      1231
# Reservoir Gas Rate (MMSCF/D)       0
# BHT (DegF)                      1501
# Comments, post SNOC input       1142
# dtype: int64

# %%
df['Difference'] = df['SiBHP (psig)'] - df['BHP (psig)']

# %%
col_names = ['Measured Depth (ft)', 'Footage Drilled / hr ']

for column in col_names:
    mean_value = df[column].mean()
    df[column].fillna(df[column].mean(), inplace=True)

# %%
df['Biozone'].fillna(method='bfill', inplace=True)
# Out:
# C:\Users\Pratham\AppData\Local\Temp\ipykernel_16356\627593489.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Biozone'].fillna(method='bfill', inplace=True)

# %%
df2 = df.iloc[:, :12]

# %%
df2
# Out:
#       Unnamed: 0  Index      Well    Leg Formation           Biozone  \
# 0              0      0  SAJAA-01  LEG C   SHUAIBA            19_S10
# 1              1      1  SAJAA-01  LEG C   KHARAIB             2_K90
# 2              2      2  SAJAA-01  LEG C   KHARAIB      20_K80 UPPER
# 3              3      3  SAJAA-01  LEG C   KHARAIB  21_K80 MID/LOWER
# 4              4      4  SAJAA-01  LEG C   KHARAIB  21_K80 MID/LOWER
# ...          ...    ...       ...    ...       ...               ...
# 1497        1497   1775  SAJAA-06  LEG D   HABSHAN            43_H90
# 1498        1498   1776  SAJAA-06  LEG D   HABSHAN            43_H90
# 1499        1499   1777  SAJAA-06  LEG D   HABSHAN            43_H90
# 1500        1500   1778  SAJAA-06  LEG D   HABSHAN            43_H90
# 1501        1501   1779  SAJAA-06  LEG D   HABSHAN            43_H90
#
#       Measured Depth (ft)  Footage Drilled / hr   WHP (psig)  SiBHP (psig)  \
# ...

# %%
leg_count = df.groupby('Well')['Leg'].count()
leg_count
# Out:
# Well
# SAJAA-01    331
# SAJAA-03    291
# SAJAA-04    340
# SAJAA-05    271
# SAJAA-06    269
# Name: Leg, dtype: int64

# %%
uniq_legs = df.groupby('Well')['Leg'].nunique()
uniq_legs
# Out:
# Well
# SAJAA-01    6
# SAJAA-03    6
# SAJAA-04    9
# SAJAA-05    4
# SAJAA-06    4
# Name: Leg, dtype: int64

# %% [markdown]
# #### number of unique legs in each well

# %%
uniq_leg_count = df.groupby(['Well', 'Leg']).size()
uniq_leg_count
# Out:
# Well      Leg
# SAJAA-01  LEG 5I              50
#           LEG 6H              62
#           LEG 7I              51
#           LEG 8G              61
#           LEG C               41
#           LEG D               66
# SAJAA-03  LEG A               40
#           LEG B               98
#           LEG D               18
#           LEG D (ST1/ST2)     47
#           LEG E               54
#           LEG G               34
# SAJAA-04  LEG B               69
#           LEG C              105
#           LEG D               33
#           LEG D (ST)           3
#           LEG D (ST2)         20
#           LEG F               18
#           LEG F (ST)          44
#           LEG F (ST2)         10
#           LEG H               38
# SAJAA-05  LEG A               87
#           LEG B               78
#           LEG C               96
#           LEG C (ST)          10
# SAJAA-06  LEG B               74
#           LEG C               76
#           LEG C (ST)          34
# ...

# %%
uniq_leg_count = df.groupby(['Well', 'Leg']).size().reset_index(name='Leg_Count')
uniq_leg_count
# Out:
#         Well              Leg  Leg_Count
# 0   SAJAA-01           LEG 5I         50
# 1   SAJAA-01           LEG 6H         62
# 2   SAJAA-01           LEG 7I         51
# 3   SAJAA-01           LEG 8G         61
# 4   SAJAA-01            LEG C         41
# 5   SAJAA-01            LEG D         66
# 6   SAJAA-03            LEG A         40
# 7   SAJAA-03            LEG B         98
# 8   SAJAA-03            LEG D         18
# 9   SAJAA-03  LEG D (ST1/ST2)         47
# 10  SAJAA-03            LEG E         54
# 11  SAJAA-03            LEG G         34
# 12  SAJAA-04            LEG B         69
# 13  SAJAA-04            LEG C        105
# 14  SAJAA-04            LEG D         33
# 15  SAJAA-04       LEG D (ST)          3
# 16  SAJAA-04      LEG D (ST2)         20
# 17  SAJAA-04            LEG F         18
# 18  SAJAA-04       LEG F (ST)         44
# 19  SAJAA-04      LEG F (ST2)         10
# 20  SAJAA-04            LEG H         38
# 21  SAJAA-05            LEG A         87
# ...
